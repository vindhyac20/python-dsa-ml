# %%
#Input: accounts = [[1,5],[7,3],[3,5]]
#Output: 10

# %%
accounts = [[1,2,3],[3,2,1]]
print(max(map(sum,accounts)))
# Out:
# 6

# %%
#candies = [4,2,1,1,2], extraCandies = 1
#Output: [true,false,false,false,false]

# %%
candies = [4,2,1,1,2]
extraCandies = 1
maxi=[]
for i in candies:
    maxi.append(i+extraCandies)
print(maxi)
# Out:
# [5, 3, 2, 2, 3]
