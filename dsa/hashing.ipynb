# %%
#to count 1 in array , tc =O(n)
num=1
arr=[2,1,4,1]
count=0
for i in arr:
    if num==i:
        count+=1
print(count)
# Out:
# 2

# %%
names = ["vin", "pri", "vin", "chan", "pri", "vin"]
count = {}

for name in names:
    count[name] = count.get(name, 0) + 1

print(count)
# Out:
# {'vin': 3, 'pri': 2, 'chan': 1}

# %%
d = {}
print(d)
# Out:
# {}

# %%
d = {}
d["vin"] = 1
print(d)
# Out:
# {'vin': 1}

# %%
d = {}
d["vin"] = 1
d["vin"] = 2
print(d)
# Out:
# {'vin': 2}
