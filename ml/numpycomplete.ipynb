# %%
import time
import numpy as np

a = np.arange(1000000)

start = time.time()
result = [x**2 for x in a]
print("Loop:", time.time() - start)

start = time.time()
result = a ** 2
print("Vectorized:", time.time() - start)
# Out:
# Loop: 0.15677142143249512
# Vectorized: 0.012668371200561523

# %%
actual      = np.array([3.0, 5.0, 2.5, 7.0, 4.0])
predictions = np.array([2.8, 5.2, 3.0, 6.5, 4.1])
error=predictions-actual
square=error**2
mse=(np.sum(square))/len(square)
print(mse)
# Out:
# 0.118

# %%
Drill 3: Full mini pipeline — write it from memory, closed book:

Generate 50 samples, 4 features using randn
Standardize column-wise
Initialize weights shape (4,1)
Compute predictions via matmul
Generate fake targets shape (50,1)
Compute and print MSE



np.random.seed(42)
X=np.random.randn(50,4)
std_scaler=(X-X.mean(axis=0))/X.std(axis=0)
W=np.random.randn(4,1)
mat=X@W
target=np.random.rand(50,1)
mse=np.mean((target-mat)**2)
print(mse)
# Out:
# 3.5198521311683937
